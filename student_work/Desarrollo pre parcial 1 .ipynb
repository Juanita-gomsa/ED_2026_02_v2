# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Ejercicio 2 
#1
def MinMax(lista):
    if len(lista)==1:
        return lista[0],lista[0]
    val1,val2=(MinMax(lista[:-1]))
    x=lista[-1]
    if x<val1:
        val1=x
    elif x>val2:
        val2=x
    return(val1,val2)

# %%
MinMax([1,4,6,3,8,2])
# Out:
# (1, 8)

# %%
#2
def picos(lista):
    if len(lista)<3:
        return 0
    if lista[-3]<lista[-2]>lista[-1]:
        return 1+picos(lista[:-1])
    else:
        return picos(lista[:-1])
    return cont

# %%
picos([2,4,3,2,8,1])
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
